# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
# ...

# %%
import urllib.request
response = urllib.request.urlopen('https://dzone.com/articles/nlp-tutorial-using-python-nltk-simple-examples')
html = response.read()
print(html)
# Out:
# b'<!DOCTYPE HTML>\n\n\n<html xmlns:ng="http://angularjs.org" id="ng-app" lang="en" ng-app="TH">\n\n<head ng-controller="DZHeadController">\n<!--\n\n##::::: ##: ########::::::: ###:::: ########:: ########:::: ##:::: ##: ####: ########:: ####: ##::: ##:: ######::\n##: ##: ##: ##.....::::::: ## ##::: ##.... ##: ##.....::::: ##:::: ##:. ##:: ##.... ##:. ##:: ###:: ##: ##... ##:\n##: ##: ##: ##::::::::::: ##:. ##:: ##:::: ##: ##:::::::::: ##:::: ##:: ##:: ##:::: ##:: ##:: ####: ##: ##:::..::\n##: ##: ##: ######:::::: ##:::. ##: ########:: ######:::::: #########:: ##:: ########::: ##:: ## ## ##: ##:: ####\n##: ##: ##: ##...::::::: #########: ##.. ##::: ##...::::::: ##.... ##:: ##:: ##.. ##:::: ##:: ##. ####: ##::: ##:\n##: ##: ##: ##:::::::::: ##.... ##: ##::. ##:: ##:::::::::: ##:::: ##:: ##:: ##::. ##::: ##:: ##:. ###: ##::: ##:\n ###. ###:: ########:::: ##:::: ##: ##:::. ##: ########:::: ##:::: ##: ####: ##:::. ##: ####: ##::. ##:. ######::\n\nSkills wanted: Java, AngularJS, Spring, Hib
# ...

# %%
from bs4 import BeautifulSoup
response = urllib.request.urlopen('https://dzone.com/articles/nlp-tutorial-using-python-nltk-simple-examples')
html = response.read()
soup = BeautifulSoup(html, "html5lib")
text = soup.get_text(strip = True)
print(text)
# Out:
# NLP Tutorial Using Python NLTK (Simple Examples) - DZone AI<div class="dz-like"
#              ng-class='{liked: status.liked}'
#              ng-click='like()'
#
# <a href="#">
#     <i ng-class="{'icon-thumbs-up-alt': status.liked, 'icon-thumbs-up liked': !status.liked}"></i>
#     <span>Like ({{ status.score }})</span>
# </a>
# </div><button type="button" ng-class="{'icon-star gold': status.saved, 'icon-star-empty': !status.saved}"
#             ng-click="save()" class="btn btn-save btn-lg"><span class="save-title">Save</span><span ng-if="status.saved"
#                                                                                                     class="d-letter">D</span>
# ...

# %%
tokens = [t for t in text.split()]
print (tokens)
# Out:
# ['NLP', 'Tutorial', 'Using', 'Python', 'NLTK', '(Simple', 'Examples)', '-', 'DZone', 'AI<div', 'class="dz-like"', "ng-class='{liked:", "status.liked}'", "ng-click='like()'", '<a', 'href="#">', '<i', 'ng-class="{\'icon-thumbs-up-alt\':', 'status.liked,', "'icon-thumbs-up", "liked':", '!status.liked}"></i>', '<span>Like', '({{', 'status.score', '}})</span>', '</a>', '</div><button', 'type="button"', 'ng-class="{\'icon-star', "gold':", 'status.saved,', "'icon-star-empty':", '!status.saved}"', 'ng-click="save()"', 'class="btn', 'btn-save', 'btn-lg"><span', 'class="save-title">Save</span><span', 'ng-if="status.saved"', 'class="d-letter">D</span>', '</button>AI', 'ZoneOver', 'a', 'million', 'developers', 'have', 'joined', 'DZone.Log', 'In/JoinSearch{{node.title}}{{node.type}}·{{', 'node.urlSource.name', '}}·by{{node.authors[0].realName', '}}Download{{node.downloads}}{{totalResults}}', 'search', 'resultsRefcardzResearchWebinarsZones|AgileAIBig', 'DataCloudDatabaseDevOpsIntegrationIoTJavaMic
# ...

# %%
freq = nltk.FreqDist(tokens)
for key, val in freq.items():
  print (str(key) + ':' + str(val))
# Out:
# NLP:12
# Tutorial:6
# Using:10
# Python:20
# NLTK:26
# (Simple:6
# Examples):2
# -:5
# DZone:8
# AI<div:1
# class="dz-like":3
# ng-class='{liked::2
# status.liked}':2
# ng-click='like()':2
# <a:11
# href="#">:4
# <i:5
# ng-class="{'icon-thumbs-up-alt'::2
# status.liked,:3
# 'icon-thumbs-up:2
# liked'::3
# !status.liked}"></i>:2
# <span>Like:2
# ({{:2
# status.score:4
# }})</span>:3
# </a>:4
# </div><button:1
# type="button":1
# ng-class="{'icon-star:4
# gold'::4
# status.saved,:4
# 'icon-star-empty'::4
# !status.saved}":4
# ng-click="save()":2
# class="btn:6
# btn-save:1
# btn-lg"><span:1
# class="save-title">Save</span><span:2
# ng-if="status.saved":2
# class="d-letter">D</span>:1
# </button>AI:1
# ZoneOver:1
# a:42
# million:1
# developers:1
# have:11
# joined:1
# DZone.Log:1
# In/JoinSearch{{node.title}}{{node.type}}·{{:1
# node.urlSource.name:1
# }}·by{{node.authors[0].realName:1
# }}Download{{node.downloads}}{{totalResults}}:1
# search:5
# ...

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
# ...

# %%
clean_tokens = tokens[:]
sr = stopwords.words('english')
for token in tokens:
  if token in stopwords.words('english'):
    clean_tokens.remove(token)

# %%
freq = nltk.FreqDist(clean_tokens)
for key, val in freq.items():
  print (str(key) + ':' + str(val))
# Out:
# NLP:12
# Tutorial:6
# Using:10
# Python:20
# NLTK:26
# (Simple:6
# Examples):2
# -:5
# DZone:8
# AI<div:1
# class="dz-like":3
# ng-class='{liked::2
# status.liked}':2
# ng-click='like()':2
# <a:11
# href="#">:4
# <i:5
# ng-class="{'icon-thumbs-up-alt'::2
# status.liked,:3
# 'icon-thumbs-up:2
# liked'::3
# !status.liked}"></i>:2
# <span>Like:2
# ({{:2
# status.score:4
# }})</span>:3
# </a>:4
# </div><button:1
# type="button":1
# ng-class="{'icon-star:4
# gold'::4
# status.saved,:4
# 'icon-star-empty'::4
# !status.saved}":4
# ng-click="save()":2
# class="btn:6
# btn-save:1
# btn-lg"><span:1
# class="save-title">Save</span><span:2
# ng-if="status.saved":2
# class="d-letter">D</span>:1
# </button>AI:1
# ZoneOver:1
# million:1
# developers:1
# joined:1
# DZone.Log:1
# In/JoinSearch{{node.title}}{{node.type}}·{{:1
# node.urlSource.name:1
# }}·by{{node.authors[0].realName:1
# }}Download{{node.downloads}}{{totalResults}}:1
# search:5
# resultsRefcardzResearchWebinarsZones|AgileAIBig:1
# ...

# %%
freq.plot(20, cumulative = False)

# %% [markdown]
# # **Tokenize Text Using NLTK**

# %%
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
#Hello Adam, how are you? I hope everything is going well.  Today is a good day, see you dude.
mt = "The Skin-On interface, developed by researchers at the University of Bristol in partnership with Telecomm ParisTech and Sorbonne University, mimics human skin in appearance but also in sensing resolution."
print(sent_tokenize(mt))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['The Skin-On interface, developed by researchers at the University of Bristol in partnership with Telecomm ParisTech and Sorbonne University, mimics human skin in appearance but also in sensing resolution.']

# %%
nltk.download('punkt')
mt = "Bonjour M. Adam, comment allez-vous? J'espère que tout va bien. Aujourd'hui est un bon jour."
print(sent_tokenize(mt, "french"))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Bonjour M. Adam, comment allez-vous?', "J'espère que tout va bien.", "Aujourd'hui est un bon jour."]

# %%
from nltk.corpus import wordnet
nltk.download("wordnet")
syn = wordnet.synsets("NLP")
print(syn[0].definition())
print(syn[0].examples())
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# the branch of information science that deals with natural language information
# []

# %%
synonyms = []
for syn in wordnet.synsets('Computer'):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())
print(synonyms)
# Out:
# ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system', 'calculator', 'reckoner', 'figurer', 'estimator', 'computer']

# %%
from nltk.stem import SnowballStemmer

# %%
print(SnowballStemmer.languages)
# Out:
# ('arabic', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'hungarian', 'italian', 'norwegian', 'porter', 'portuguese', 'romanian', 'russian', 'spanish', 'swedish')

# %% [markdown]
# # The Greate **Lemmatization !!!**

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
print(stemmer.stem('Lemmatization'))
# Out:
# lemmat

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize('calling', pos = "v"))
# Out:
# call

# %%
stemmer = PorterStemmer() 
lemmatizer = WordNetLemmatizer() 
print(stemmer.stem('stones')) 
print(stemmer.stem('speaking')) 
print(stemmer.stem('bedroom')) 
print(stemmer.stem('jokes')) 
print(stemmer.stem('lisa')) 
print(stemmer.stem('Lemmatization')) 
print('----------------------') 
print(lemmatizer.lemmatize('stones')) 
print(lemmatizer.lemmatize('speaking'))
print(lemmatizer.lemmatize('bedroom'))
print(lemmatizer.lemmatize('jokes'))
print(lemmatizer.lemmatize('lisa'))
print(lemmatizer.lemmatize('Lemmatization'))
# Out:
# stone
# speak
# bedroom
# joke
# lisa
# lemmat
# ----------------------
# stone
# speaking
# bedroom
# joke
# lisa
# Lemmatization
